# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunK-ML/Data-Preprocessing-Sales-Stores-Features_Data_Set/blob/main/Sales_Stores_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import all the CSV data files by using pandas**

# %%
# Import all the CSV data files by using pandas

import pandas as pd

df_sales = pd.read_csv("/content/sales_data_set.csv")

df_stores = pd.read_csv("/content/stores_data_set.csv")

df_features = pd.read_csv("/content/Features_data_set.csv")

df_sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
df_stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
df_features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
# check the columns names of different tables

df_sales.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %%
df_stores.columns
# Out:
# Index(['Store', 'Type', 'Size'], dtype='object')

# %%
df_features.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %% [markdown]
# # **Merge the tables **

# %%
# Merge the table acc. to the columns name and data
# Table df_sales and df_stores

df_sales_stores = pd.merge(df_sales, df_stores, on="Store")

df_sales_stores
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
# [421570 rows x 7 columns]

# %%
# Merge the Tables df_sales_stores and df_features

df_sales_stores_features = pd.merge(df_sales_stores, df_features, on=["Store", "Date", "IsHoliday"])

df_sales_stores_features
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# ...

# %% [markdown]
# # **Data Preprocessing **

# %%
# Now Data Preprocessing

df_sales_stores_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
# dtypes: bool(1), float64(10), int64(3), object(2)
# ...

# %%
df_sales_stores_features.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment'],
#       dtype='object')

# %% [markdown]
# # **Data Cleaning**

# %%
from typing import Text
# In table date type is mistake .. change the date type ...... And fill the nun values in the tables

df_sales_stores_features["Date"] = pd.to_datetime(df_sales_stores_features["Date"],format = "%d/%m/%Y")

df_sales_stores_features.fillna(0, inplace=True)

# %%
df_sales_stores_features.isna()
# Out:
#         Store   Dept   Date  Weekly_Sales  IsHoliday   Type   Size  \
# 0       False  False  False         False      False  False  False
# 1       False  False  False         False      False  False  False
# 2       False  False  False         False      False  False  False
# 3       False  False  False         False      False  False  False
# 4       False  False  False         False      False  False  False
# ...       ...    ...    ...           ...        ...    ...    ...
# 421565  False  False  False         False      False  False  False
# 421566  False  False  False         False      False  False  False
# 421567  False  False  False         False      False  False  False
# 421568  False  False  False         False      False  False  False
# 421569  False  False  False         False      False  False  False
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             False       False      False      False      False      False
# ...

# %%
df_sales_stores_features
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1 2010-02-05      24924.50      False    A  151315
# 1           1     1 2010-02-12      46039.49       True    A  151315
# 2           1     1 2010-02-19      41595.55      False    A  151315
# 3           1     1 2010-02-26      19403.54      False    A  151315
# 4           1     1 2010-03-05      21827.90      False    A  151315
# ...       ...   ...        ...           ...        ...  ...     ...
# 421565     45    98 2012-09-28        508.37      False    B  118221
# 421566     45    98 2012-10-05        628.10      False    B  118221
# 421567     45    98 2012-10-12       1061.02      False    B  118221
# 421568     45    98 2012-10-19        760.01      False    B  118221
# 421569     45    98 2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# ...

# %% [markdown]
# # **Queries**

# %%
#1.)Identify average customer visit in Type C store in June Month .
#2.)Find the highest sales in each store type on Holiday season.
#3.)What is the expected sales of each depeartment when the unemployment factor is greater than 7.
#4.)Aggregate net sales for each department in month wise.
#5.)Identify the performance of the store on weekwise, without offers.

# %%
#1.)Identify average customer visit in Type C store in June Month .
